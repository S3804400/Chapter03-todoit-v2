# %% [markdown]
# <a href="https://colab.research.google.com/github/S3804400/Chapter03-todoit-v2/blob/main/ReyesM01Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install alpha_vantage

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
ALPHA_VANTAGE_API_KEY = "A1NPMDDHISODNN0Y"
crypto_api = CryptoCurrencies(key=ALPHA_VANTAGE_API_KEY,
                              output_format= "pandas")

# %%
data, meta_data = crypto_api.get_digital_currency_daily(
    symbol="BTC",
    market="EUR"
)

# %%
crypto_api.get_digital_currency_exchange_rate(
    from_currency="BTC",
    to_currency="USD"
)[0].transpose()
# Out:
#                       Realtime Currency Exchange Rate
# 1. From_Currency Code                             BTC
# 2. From_Currency Name                         Bitcoin
# 3. To_Currency Code                               USD
# 4. To_Currency Name              United States Dollar
# 5. Exchange Rate                       61228.44000000
# 6. Last Refreshed                 2024-05-12 21:55:01
# 7. Time Zone                                      UTC
# 8. Bid Price                           61227.88800000
# 9. Ask Price                           61228.68700000

# %%
import requests
import pandas as pd
from io import BytesIO

# %%
AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
    "function": "CRYPTO_INTRADAY",
    "symbol": "ETH",
    "market": "USD",
    "interval": "30min",
    "outputsize": "full",
    "apikey": ALPHA_VANTAGE_API_KEY
}
r = requests.get(AV_API_URL, params=parameters)
data = r.json()
df = (
    pd.DataFrame(data["Time Series Crypto (30min)"]) .transpose()
)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-04f97e12073e> in <cell line: 13>()
#      11 data = r.json()
#      12 df = (
# ---> 13     pd.DataFrame(data["Time Series Crypto (30min)"]) .transpose()
#      14 )
#      15 df
#
# KeyError: 'Time Series Crypto (30min)'

# %%
from pycoingecko import CoinGeckoAPI
from datetime import datetime
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-50-4288b654ba9e> in <cell line: 1>()
# ----> 1 from pycoingecko import CoinGeckoAPI
#       2 from datetime import datetime
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'pycoingecko'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install CoinGecko

# %%
from pycoingecko import CoinGeckoAPI
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-10497677c14c> in <cell line: 1>()
# ----> 1 from pycoingecko import CoinGeckoAPI
#       2 from datetime import datetime
#
# ModuleNotFoundError: No module named 'pycoingecko'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install intrinio_sdk
import intrinio_sdk as intrinio
import pandas as pd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.9 MB/s eta 0:00:00
# ...

# %%
import intrinio_sdk as intrinio
import pandas as pd

# %%
intrinio.ApiClient().set_api_key("OjQyN2FiN2E1YzNiMDcwNGZlNjU0N2NiNWVlYzljMjgw")
security_api = intrinio.SecurityApi()

# %%
# !pip install nasdaq-data-link

# %%
intrinio.ApiClient().set_api_key("OjQyN2FiN2E1YzNiMDcwNGZlNjU0N2NiNWVlYzljMjgw")
security_api = intrinio.SecurityApi()

# %%
import pandas as pd
import nasdaqdatalink

# %%
nasdaqdatalink.ApiConfig.api_key = "KTZmz8bsHmmisdTMCcs7"

# %%
dfnas = nasdaqdatalink.get(dataset="WIKI/AAPL",
                        start_date="2013-01-01",
                        end_date="2023-12-31")

# %%
print(f"Downloaded {len(df)} rows of data.")
df.head()
# Out:
# Downloaded 3270 rows of data.
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2011-01-03  11.630000  11.795000  11.601429  11.770357   9.951283  445138400
# 2011-01-04  11.872857  11.875000  11.719643  11.831786  10.003217  309080800
# 2011-01-05  11.769643  11.940714  11.767857  11.928571  10.085044  255519600
# 2011-01-06  11.954286  11.973214  11.889286  11.918929  10.076895  300428800
# 2011-01-07  11.928214  12.012500  11.853571  12.004286  10.149058  311931200

# %%
import pandas as pd
import yfinance as yf

# %%
df = yf.download("AAPL",
                 start="2011-01-01",
                 end="2023-12-31",
                 progress=False)
print(f"Downloaded {len(df)} rows of data.")
df
aapl_data = yf.Ticker("AAPL")
aapl_data.history()
# Out:
# Downloaded 3270 rows of data.
#                                  Open        High         Low       Close  \
# Date
# 2024-04-11 00:00:00-04:00  168.111980  175.222347  167.932232  174.802902
# 2024-04-12 00:00:00-04:00  174.023961  178.118413  173.974040  176.310867
# 2024-04-15 00:00:00-04:00  175.122467  176.390751  172.266340  172.456085
# 2024-04-16 00:00:00-04:00  171.517359  173.524631  168.042077  169.150574
# 2024-04-17 00:00:00-04:00  169.380266  170.418850  167.772446  167.772446
# 2024-04-18 00:00:00-04:00  167.802400  168.411575  166.324409  166.813736
# 2024-04-19 00:00:00-04:00  165.984872  166.174602  163.857753  164.776505
# 2024-04-22 00:00:00-04:00  165.295798  167.033431  164.546814  165.615356
# 2024-04-23 00:00:00-04:00  165.126031  166.823726  164.696606  166.673920
# 2024-04-24 00:00:00-04:00  166.314410  169.070681  165.984870  168.791061
# 2024-04-25 00:00:00-04:00  169.300369  170.378908  167.922233  169.659882
# ...

# %%
import pandas as pd
import nasdaq-data-link
nasdaqdatalink.ApiConfig.api_key = "KTZmz8bsHmmisdTMCcs7"
df = nasdaqdatalink.get(dataset="WIKI/AAPL",
                        start_date="2011-01-01",
                        end_date="2021-12-31")
print(f"Downloaded {len(df)} rows of data.")
df.head()
# Out:
#   File "<ipython-input-17-ad20f0047b5e>", line 2
#     import nasdaq-data-link
#                  ^
# SyntaxError: invalid syntax

# %%
nasdaqdatalink.ApiConfig.api_key = "KTZmz8bsHmmisdTMCcs7"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-dd2d8f8fa682> in <cell line: 1>()
# ----> 1 nasdaqdatalink.ApiConfig.api_key = "KTZmz8bsHmmisdTMCcs7"
#
# NameError: name 'nasdaqdatalink' is not defined
